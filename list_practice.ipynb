# %% [markdown]
# # 문제 1.
# - 문자 10개를 저장할 수 있는 리스트를 만들고 10개의 문자를 입력받아 입력받은 문자를 이어서 출력하는 프로그램을 작성하시오.
# - 입력 예: A B C D E F G H I J
# - 출력 예: ABCDEFGHIJ

# %%
#done
list1 = []
for i in range(10) :
    word =(input("문자를 입력하세요 : "))
    list1 += word

print(list1)
# Out:
#   File "<ipython-input-11-937e166c51c3>", line 6
#     print(list1[:11]])
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 문제 2.
# - 10개의 문자를 입력받아서 첫 번째 네 번째 일곱 번째 입력받은 문자를 차례로 출력하는 프로그램을 작성하시오.
# - 입력 예: A B C D E F G H I J
# - 출력 예: A D G

# %%
#done
list1 = []
for i in range(10) :
    word =(input("문자를 입력하세요 : "))
    list1 += word
print(list1[0],list1[3],list1[6])

# %% [markdown]
# # 문제 3.
# - 빈 리스트을 선언하고 정수를 차례로 입력받다가 0 이 입력되면 0 을 제외하고 그 때까지 입력된 정수를 가장 나중에 입력된 정수부터 차례대로 출력하는 프로그램을 작성하시오.
# - 입력 예:
#     * 3
#     * 5
#     * 10
#     * 55
#     * 0
# - 출력 예: 55 10 5 3

# %%
#done
list_1 = []
num = 1
while num != 0 :
  num= int(input("정수를 입력하세요 : "))
  list_1.append(num)
  if num == 0 :
    break
list_1.reverse()
list_1.remove(0)
print(list_1)
# Out:
# 정수를 입력하세요 : 99
# 정수를 입력하세요 : 88
# 정수를 입력하세요 : 77
# 정수를 입력하세요 : 0
# [77, 88, 99]

# %% [markdown]
# # 문제 4.
# - 1반부터 6반까지의 평균점수를 저장한 후 두 반의 반 번호를 입력받아 두 반 평균점수의 합을 출력하는 프로그램을 작성하시오.
# - 반별 평균점수는 초기값으로 1반부터 차례로 85.6 79.5 83.1 80.0 78.2 75.0으로 초기화하고,
# - 출력은 소수 두 번째 자리에서 반올림하여 소수 첫째자리까지 한다.
# - 입력 예: 1 3 (1반 3반을 의미)
# - 출력 예: 168.7

# %%
#done
score = [85.6,79.5,83.1,80.0,78.2,75]
class_1 = int((input("첫 번째 반의 번호를 입력하세요 : ")))
class_2 = int((input("두 번째 반의 번호를 입력하세요 : ")))

print((score[class_1-1])+(score[class_2-1]))
# Out:
# 첫 번째 반의 번호를 입력하세요 : 1
# 두 번째 반의 번호를 입력하세요 : 2
# 165.1

# %% [markdown]
# # 문제 5.
# - 10개의 정수를 입력받아 그 중 가장 작은 수를 출력하는 프로그램을 작성하시오.
# - 입력 예: 5 10 8 55 6 31 12 24 61 2
# - 출력 예: 2

# %%
#done
list_1 = []
for i in range(10) :
  num = (input("정수를 입력하세요 : "))
  list_1 += num
print(min(list_1))
# Out:
# 정수를 입력하세요 : 4
# 정수를 입력하세요 : 7
# 정수를 입력하세요 : 0
# 정수를 입력하세요 : 2
# 정수를 입력하세요 : 1
# 정수를 입력하세요 : 67
# 정수를 입력하세요 : 99
# 정수를 입력하세요 : 100
# 정수를 입력하세요 : 2
# 정수를 입력하세요 : 55
# 0

# %% [markdown]
# # 문제 6.
# - 10개의 정수를 입력받아 100 미만의 수 중 가장 큰 수와 100 이상의 수 중 가장 작은 수를 출력하는 프로그램을 작성하시오.
# - 입력 예: 88 123 659 15 443 1 99 313 105 48
# - 출력 예: 99 105

# %%
#done
list_1 = []
list_2 = []
som = 0
for i in range(10) :
  number =int(input("정수를 입력하세요 : "))
  som += number
  
  if number < 100 :
    list_1.append(number)
  elif number >= 100 :
    list_2.append(number)  
print(max(list_1), min(list_2))
# Out:
# 정수를 입력하세요 : 4
# 정수를 입력하세요 : 99
# 정수를 입력하세요 : 209
# 정수를 입력하세요 : 445
# 정수를 입력하세요 : 1
# 정수를 입력하세요 : 90
# 정수를 입력하세요 : 223
# 정수를 입력하세요 : 99
# 정수를 입력하세요 : 843
# 정수를 입력하세요 : 92
# 99 209

# %% [markdown]
# # 문제 7.
# - 10개의 정수를 입력받아 리스트에 저장한 후 짝수 번째 입력된 값의 합과 홀수 번째 입력된 값의 평균을 출력하는 프로그램을 작성하시오.
# - 평균은 반올림하여 소수첫째자리까지 출력한다.
# - 입력 예: 95 100 88 65 76 89 58 93 77 99
# - 출력 예:
#     * sum : 446
#     * avg : 78.8

# %%
#done

num_list = []
even_list = []
odd_list = []
i = 1
for i in range(10) :
    num = int(input("정수를 입력하세요 : "))
    num_list.append(num)
    if  i % 2 == 0 :
        odd_list.append(num)
    else :
        even_list.append(num)

result_even = sum(even_list)
result_odd = sum(odd_list) / 5

print("sum : {}\navg : {}".format(result_even,result_odd))
# Out:
#   File "<ipython-input-44-bbfc2dd60d02>", line 10
#     for i in num_list[i] :
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # 문제 8.
# - 10개의 정수를 입력받아 리스트에 저장한 후 내림차순으로 정렬하여 출력하시오.
# - 입력 예: 95 100 88 65 76 89 58 93 77 99
# - 출력 예: 100 99 95 93 89 88 77 76 65 58

# %%
#done
list_1 = []
for i in range (10) :
  num = int(input("정수를 입력하세요 : "))
  list_1.append(num)
list_1.sort()
list_1.reverse()
print(list_1)
# Out:
# 정수를 입력하세요 : 77
# 정수를 입력하세요 : 20
# 정수를 입력하세요 : 34
# 정수를 입력하세요 : 9
# 정수를 입력하세요 : 10
# 정수를 입력하세요 : 24
# 정수를 입력하세요 : 99
# 정수를 입력하세요 : 102
# 정수를 입력하세요 : 33
# 정수를 입력하세요 : 202
# [202, 102, 99, 77, 34, 33, 24, 20, 10, 9]
