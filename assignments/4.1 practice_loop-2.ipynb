# %% [markdown]
# # 문제 1.(for)
# ## for 문을 이용하여 1부터 입력받은 정수까지의 합을 구하여 출력하는 프로그램을 작성하시오.
# - 100 이하의 양의 정수만 입력된다.
# - 입력 예: 10
# - 출력 예: 55

# %%
#done
num = int(input("정수를 입력하세요 : "))
sum = 0
if num > 100 :
    print("100이하의 양수만 입력됩니다.")
else :
    for i in range (num+1) :
        sum += i
    print(sum)
# Out:
#   File "<ipython-input-1-d19bb9cb86e6>", line 3
#     for i in range (1:num+1) :
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 문제 2.
# ## 정수를 계속 입력받다가 100 이상의 수가 입력이 되면 마지막 입력된 수를 포함하여 합계와 평균을 출력하는 프로그램을 작성하시오.
#
# - 평균은 반올림하여 소수 첫째자리까지 출력한다.

# %%
#done
sum = 0
list_1 = []
num = 1
while num < 100 :
    num = int(input("정수를 입력하세요 : "))
    sum += num
    list_1.append(num)
    if num >= 100 :
        print("합계 : {}, 평균 : {}".format(sum,sum/len(list_1)))

# %% [markdown]
# # 문제 3.
# ## 정수를 입력받아서 3의 배수가 아닌 경우에는 아무 작업도 하지 않고, 3의 배수인 경우에는 3으로 나눈몫을 출력하는 작업을 반복하다가 -1이 입력되면 종료하는 프로그램을 작성하시오.
# 예시:
# - 5
# - 12
# - <h2>4</h2>
# - 21
# - <h2>7</h2>
# - 100
# - -1

# %%
#done
num = 1
while num != -1 :
    num = int(input("정수를 입력하세요 : "))
    if num % 3 == 0 :
      print(num//3)
    elif num == -1 :
      break

# %% [markdown]
# # 보너스(for)
# ## 아래와 같은 모양으로 출력하는 프로그램을 작성하시오.
#  - 사용자에게 숫자를 입력받아 입력 받은 높이 만큼의 삼각형을 출력하시오.
#  - 입력 예: 5

# %%
    *
   **
  ***
 ****
*****

# %%
#done
n = int(input("숫자를 입력하세요 :"))
for i in range (0,n+1) :
    result = "*"*i
    print(result.rjust(10),sep=" ")

# %% [markdown]
# # 문제 4.
# ## 아래와 같이 나라 이름을 출력하고 숫자를 입력받아 해당하는 나라의 수도를 출력하는 작업을 반복하다가 해당하는 번호 이외의 숫자가 입력되면 "none"라고 출력한 후 종료하는 프로그램을 작성하시오.
#
# * 각 나라의 수도 :
# - 대한민국 = 서울(Seoul)
# - 미국 = 워싱턴(Washington)
# - 일본 = 동경(Tokyo)
# - 중국 = 북경(Beijing)
#
# 예시
# 입력 예:
# 1. Korea
# 2. USA
# 3. Japan
# 4. China
# number? 1
#
# 출력 예:
# Seoul
#
# 1. Korea
# 2. USA
# 3. Japan
# 4. China
# number? 5
#
# none

# %%
#done
country = ["Korea", "USA", "Japan", "China"]
capital = ["Seoul", "Washington", "Tokyo", "Beijing"]
print(country)
i = 1
while i < 5  :
    num = int(input("정수를 입력하세요 : "))
    print(capital[num-1])

    if num > 4 :
    print("None")
# Out:
#   File "<ipython-input-1-6b6da7dc0523>", line 11
#     print("None")
#         ^
# IndentationError: expected an indented block

# %%
#

# %% [markdown]
# # 문제 5.
# ## 0 이상의 정수들이 공백으로 구분되어 반복적으로 주어진다. 0이 입력되면 반복문을 멈추고 그 전까지 입력받은 수들에 대하여 홀수의 개수와 짝수의 개수를 출력하는 프로그램을 작성하시오.
# - 입력 예: 9 7 10 5 33 65 0
# - 출력 예:
#  odd : 5
#  even : 1

# %%
#done

list_odd = []
list_even = []
num = 1
while num != 0 :
    num= int(input("정수를 입력하세요 : "))
    if num % 2 == 0 :
        list_even.append(num)
    elif num % 2 == 1 :
        list_odd.append(num)
    elif num == 0 :
        break
print("odd : {}, even : {}".format(len(list_odd), len(list_even)))

# %% [markdown]
# # 문제 6.
# ## 삼각형의 밑변의 길이와 높이를 입력받아 넓이를 출력하고, "Continue? "에서 하나의 문자를 입력받아 그 문자가 'Y' 나 'y' 이면 작업을 반복하고 다른 문자이면 종료하는 프로그램을 작성하시오.
#
# - 넓이는 반올림하여 소수 첫째자리까지 출력한다.
# 예시
# ###### Base = 11
# ###### Height = 5
# ###### Triangle width = 27.5
# ###### Continue? Y
# ###### Base = 10
# ###### Height = 10
# ###### Triangle width = 50.0
# ###### Continue? N

# %%
#done
while (1) :
    base = int(input("밑변의 길이를 입력하세요 : "))
    height = int(input("높이를 입력하세요 : "))
    print("Triangle width : {}".format(base*height/2))
    question = str(input("continue ?"))
    if question == "x" or question == "y" :
        continue
    else :
        break
# Out:
#   File "<ipython-input-2-7722bef13036>", line 6
#     question = (input("Continue ? "))
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 문제 7.(for)
# ## 100 이하의 두 개의 정수를 입력받아 작은 수부터 큰 수까지 차례대로 출력하는 프로그램을 작성하시오.
# - 입력 예: 5 10
# - 출력 예: 5 6 7 8 9 10

# %%
#done
num_1 = int(input("첫 번째 정수를 입력하세요 : "))
num_2 = int(input("두 번째 정수를 입력하세요 : "))
if num_1 > num_2 :
    for i in range(num_2, num_1+1) :
        print(i)
elif num_1 < num_2 :
    for i in range(num_1, num_2+1) :
        print(i)
# Out:
#   File "<ipython-input-9-46e8aad10698>", line 9
#     print(range(num_1:num_2 + 1))
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # 문제 8.(for)
# ## 두 개의 정수를 입력받아 두 정수 사이(두 정수를 포함)에 3의 배수이거나 5의 배수인 수들의 합과 평균을 출력하는 프로그램을 작성하시오.
# - 평균은 반올림하여 소수 첫째자리까지 출력한다.
# - 입력 예: 10 15
# - 출력 예:
# sum : 37
# avg : 12.3

# %%
#done
num_1 = int(input("첫 번째 정수를 입력하세요 : "))
num_2 = int(input("두 번째 정수를 입력하세요 : "))
list = []
sum = 0
if num_1 > num_2 :
    for i in range(num_2, num_1+1) :
        if i % 3 == 0 or i % 5 == 0 :
          sum += i
          list.append(i)
elif num_1 < num_2 :
    for i in range(num_1, num_2+1) :
        if i % 3 == 0 or i % 5 == 0 :
          sum += i
          list.append(i)
print("sum : {}, avg : {}".format(sum,round(sum/len(list),1)))

# %% [markdown]
# # 문제 9. (for)
# ## 2부터 9까지의 수 중 2개를 입력받아 입력받은 수 사이의 구구단을 출력하는 프로그램을 작성하시오.
# - 단 반드시 먼저 입력된 수의 구구단부터 아래의 형식에 맞게 출력하여야 한다.
# - 구구단 사이의 공백은 3칸이다.
# - 입력 예: 5 3
# - 출력 예:
# 5 * 1 =  5   4 * 1 =  4   3 * 1 =  3
# 5 * 2 = 10   4 * 2 =  8   3 * 2 =  6
# 5 * 3 = 15   4 * 3 = 12   3 * 3 =  9
# 5 * 4 = 20   4 * 4 = 16   3 * 4 = 12
# 5 * 5 = 25   4 * 5 = 20   3 * 5 = 15
# 5 * 6 = 30   4 * 6 = 24   3 * 6 = 18
# 5 * 7 = 35   4 * 7 = 28   3 * 7 = 21
# 5 * 8 = 40   4 * 8 = 32   3 * 8 = 24
# 5 * 9 = 45   4 * 9 = 36   3 * 9 = 27

# %%
#done
num = int(input("2부터 9까지의 수를 입력하세요 : "))
num2 = int(input("2부터 9까지의 수를 입력하세요 : "))
if num>num2 :
    for i in range(1,10) :
        for a in range (1,num-num2+2) :
            a += -1
            gugu= (num+a) * i
            print("{} * {} = {}".format(num-a,i,gugu),end="   ")
elif num2>num : 
    for i in range(1,10) :
        for b in range (1,num2-num+2) :
            b += -1
            gugu= (num+b) * i
            print("{} * {} = {}".format(num+b,i,gugu),end="   ")

# %% [markdown]
# # 보너스2 (for)
# ## 아래와 같은 모양으로 출력하는 프로그램을 작성하시오.
#  - 사용자에게 숫자를 입력받아 입력 받은 높이 만큼의 삼각형을 출력하시오.
#  - 입력 예: 5

# %%
*****
 ****
  ***
   **
    *

# %%
#done
n = int(input("숫자를 입력하세요 :"))
for i in range (n,0,-1) :
    result = "*"*i
    print(result.rjust(10),sep=" ")
